# %% [markdown]
# # JSON examples and exercise
# ****
# + get familiar with packages for dealing with JSON
# + study examples with JSON strings and files
# + work on exercise to be completed and submitted
# ****
# + reference: http://pandas.pydata.org/pandas-docs/stable/io.html#io-json-reader
# + data source: http://jsonstudio.com/resources/
# ****

# %%
# imports for Python, Pandas
import pandas as pd

# %%
import json
from pandas.io.json import json_normalize

# %% [markdown]
# Using data in file 'data/world_bank_projects.json',
# 1. Find the 10 countries with most projects
# 2. Find the top 10 major project themes (using column 'mjtheme_namecode')
# 3. In 2. above you will notice that some entries have only the code and the name is missing. Create a dataframe with the missing names filled in.

# %% [markdown]
# Let's start with reading json file to a dataframe and brifly examiming it:

# %%
# reading json file to a dataframe 
df = pd.read_json('data/world_bank_projects.json')
df.head()
# Out:
#                                     _id  approvalfy board_approval_month  \
# 0  {'$oid': '52b213b38594d8a2be17c780'}        1999             November
# 1  {'$oid': '52b213b38594d8a2be17c781'}        2015             November
# 2  {'$oid': '52b213b38594d8a2be17c782'}        2014             November
# 3  {'$oid': '52b213b38594d8a2be17c783'}        2014              October
# 4  {'$oid': '52b213b38594d8a2be17c784'}        2014              October
#
#       boardapprovaldate                                 borrower  \
# 0  2013-11-12T00:00:00Z  FEDERAL DEMOCRATIC REPUBLIC OF ETHIOPIA
# 1  2013-11-04T00:00:00Z                    GOVERNMENT OF TUNISIA
# 2  2013-11-01T00:00:00Z   MINISTRY OF FINANCE AND ECONOMIC DEVEL
# 3  2013-10-31T00:00:00Z   MIN. OF PLANNING AND INT'L COOPERATION
# 4  2013-10-31T00:00:00Z                      MINISTRY OF FINANCE
#
#             closingdate                              country_namecode  \
# ...

# %% [markdown]
# 1. We see that 3 at least different columns are used to describe country. Let's check if there are any missing values in corresponding columns:

# %%
print("Count mot null valueas same for 3 columns: " + 
      str(df.country_namecode.notnull().sum() == df.countrycode.notnull().sum() == df.countryname.notnull().sum()))

print("Count of missing values: " + str(df.country_namecode.isnull().sum()))
# Out:
# Count mot null valueas same for 3 columns: True
# Count of missing values: 0

# %% [markdown]
# As we can use any column as country name, let's use 'countryname' to get top 10 countries:

# %%
# finging top 10 countries
df.countryname.value_counts()[:10]
# Out:
# Republic of Indonesia              19
# People's Republic of China         19
# Socialist Republic of Vietnam      17
# Republic of India                  16
# Republic of Yemen                  13
# People's Republic of Bangladesh    12
# Kingdom of Morocco                 12
# Nepal                              12
# Republic of Mozambique             11
# Africa                             11
# Name: countryname, dtype: int64

# %% [markdown]
# We see Africa in the list, which look suspicios, as Africa is a continent, not a country. Let's take a look at rows with this value:

# %%
# getting corresponding rows to "Africa"
df[df.countryname=='Africa']
# Out:
#                                       _id  approvalfy board_approval_month  \
# 45   {'$oid': '52b213b38594d8a2be17c7ad'}        2014            September
# 46   {'$oid': '52b213b38594d8a2be17c7ae'}        2014            September
# 51   {'$oid': '52b213b38594d8a2be17c7b3'}        2014            September
# 58   {'$oid': '52b213b38594d8a2be17c7ba'}        2014               August
# 65   {'$oid': '52b213b38594d8a2be17c7c1'}        2014               August
# 99   {'$oid': '52b213b38594d8a2be17c7e3'}        2013                 June
# 167  {'$oid': '52b213b38594d8a2be17c827'}        2013                  May
# 184  {'$oid': '52b213b38594d8a2be17c838'}        2013                  May
# 287  {'$oid': '52b213b38594d8a2be17c89f'}        2013                March
# 353  {'$oid': '52b213b38594d8a2be17c8e1'}        2013              January
# 449  {'$oid': '52b213b38594d8a2be17c941'}        2013              October
#
#         boardapprovaldate                       borrower  \
# ...

# %% [markdown]
# It looks like in some cases project were related to multiple countires. Should we need futher work whith this data, we would have to investigate the matter further.

# %% [markdown]
# 2. To find the top 10 major project themes using column 'mjtheme_namecode', let's check what we have in thia column by defalt:

# %%
# 'namecode' column
df.mjtheme_namecode.head()
# Out:
# 0    [{'code': '8', 'name': 'Human development'}, {...
# 1    [{'code': '1', 'name': 'Economic management'},...
# 2    [{'code': '5', 'name': 'Trade and integration'...
# 3    [{'code': '7', 'name': 'Social dev/gender/incl...
# 4    [{'code': '5', 'name': 'Trade and integration'...
# Name: mjtheme_namecode, dtype: object

# %% [markdown]
# This was a nested part in json, which was not parsed to DataFrame properly, so let's use 'json_normalize' to get the data which we need:

# %%
# parsing themes from the file using json_normalize
json_string = json.load((open('data/world_bank_projects.json'))) 
themes_df = json_normalize(json_string, 'mjtheme_namecode')
themes_df.head()
# Out:
#   code                                   name
# 0    8                      Human development
# 1   11
# 2    1                    Economic management
# 3    6  Social protection and risk management
# 4    5                  Trade and integration

# %% [markdown]
# Here we can see that missing values are represented by empty string. Let's replace it with NaN:

# %%
#importing numy which we need for NaN value
import numpy as np

#replacing '' with NaN
themes_df.replace('', np.nan, inplace = True)
themes_df.head()
# Out:
#   code                                   name
# 0    8                      Human development
# 1   11                                    NaN
# 2    1                    Economic management
# 3    6  Social protection and risk management
# 4    5                  Trade and integration

# %% [markdown]
# Let's check how many missing and unick values we have in themes_df:

# %%
print("'code' missing values count:  " + str(themes_df.code.isnull().sum()))
print("'name' missing values count:  " + str(themes_df.name.isnull().sum()))
# Out:
# 'code' missing values count:  0
# 'name' missing values count:  122

# %%
print("'code' unique values:  " + str(len(themes_df.code.unique())))
print("'name' unique values:  " + str(len(themes_df.name.unique())))
# Out:
# 'code' unique values:  11
# 'name' unique values:  12

# %% [markdown]
# 'code' has no missing values, while 'name' has 122. 'code' and 'name' has samr number of unique values, taking 'Nan' into consideration.

# %% [markdown]
# Now let's check the most popular themes using 'name' column, ignoring missing values for now (we'll get there later).

# %%
# most popular themes using 'name'
themes_df.name.value_counts()[:10]
# Out:
# Environment and natural resources management    223
# Rural development                               202
# Human development                               197
# Public sector governance                        184
# Social protection and risk management           158
# Financial and private sector development        130
# Social dev/gender/inclusion                     119
# Trade and integration                            72
# Urban development                                47
# Economic management                              33
# Name: name, dtype: int64

# %% [markdown]
# 3. Now we'll replace missing values using 'code' column.
# First, let's construct dataframe which will serve like a distionary for theme's 'name' and 'code', and then we'll use it to replace missing values.

# %%
# constructing dataframe which will serve like a distionary for theme's 'name' and 'code':
d = themes_df.dropna().drop_duplicates().set_index('code')
d
# Out:
#                                               name
# code
# 8                                Human development
# 1                              Economic management
# 6            Social protection and risk management
# 5                            Trade and integration
# 2                         Public sector governance
# 11    Environment and natural resources management
# 7                      Social dev/gender/inclusion
# 4         Financial and private sector development
# 10                               Rural development
# 9                                Urban development
# 3                                      Rule of law

# %%
#replacing missing values in themes_df using 'code' to 'name' mapping
themes_df.name = themes_df.code.map(lambda x: d.loc[x][0])
themes_df.head()
# Out:
#   code                                          name
# 0    8                             Human development
# 1   11  Environment and natural resources management
# 2    1                           Economic management
# 3    6         Social protection and risk management
# 4    5                         Trade and integration

# %%
#checking is we have any NaN left
print("'code' missing values count:  " + str(themes_df.code.isnull().sum()))
print("'name' missing values count:  " + str(themes_df.name.isnull().sum()))
# Out:
# 'code' missing values count:  0
# 'name' missing values count:  0

# %% [markdown]
# Now that we fixed missing values, let's re-calculate the most popular themes

# %%
# most popular themes
themes_df.name.value_counts()[:10]
# Out:
# Environment and natural resources management    250
# Rural development                               216
# Human development                               210
# Public sector governance                        199
# Social protection and risk management           168
# Financial and private sector development        146
# Social dev/gender/inclusion                     130
# Trade and integration                            77
# Urban development                                50
# Economic management                              38
# Name: name, dtype: int64
